# %% [markdown]
# # Miscellaneous reading
#
# There are some files which don't fit within the standard CMIP6 output but which we would nonetheless like to read. For this purpose, we have `netcdf_scm.misc_readers`. At the moment it only helps us to read hemispheric-mean data for CMIP6 input concentrations, but more options can be added as needed (pull requests welcome :)).

# %% [markdown]
# ## CMIP6 concentrations input
#
# The CMIP6 input concentrations are provided on a grid. However, hemispheric mean data was also provided. These can be read as shown below.

# %%
import os.path

import matplotlib.pyplot as plt

from netcdf_scm.misc_readers import read_cmip6_concs_gmnhsh
# Out:
# can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
# Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
# numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
# can't resolve package from __spec__ or __package__, falling back on __name__ and __path__

# %%
TEST_DATA_DIR = os.path.join("..", "tests", "test-data")
TEST_HISTORICAL_FILE = os.path.join(
    TEST_DATA_DIR, 
    "mole-fraction-of-carbon-dioxide-in-air_input4MIPs_GHGConcentrations_CMIP_UoM-CMIP-1-2-0_gr1-GMNHSH_000001-201412.nc"
)
TEST_PROJECTION_FILE = os.path.join(
    TEST_DATA_DIR, 
    "mole-fraction-of-carbon-dioxide-in-air_input4MIPs_GHGConcentrations_ScenarioMIP_UoM-MESSAGE-GLOBIOM-ssp245-1-2-1_gr1-GMNHSH_201501-250012.nc"
)

# %%
historical_concs = read_cmip6_concs_gmnhsh(TEST_HISTORICAL_FILE)
historical_concs.head()
# Out:
# Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
# Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
# time                                                                                                                                                               0001-01-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.876678
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              278.555908
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.197449
#
# time                                                                                                                                                               0001-02-16 00:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              278.231598
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              279.183929
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.279266
#
# time                                                                                                                                                               0001-03-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              278.551178
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              279.804108
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.298248
#
# time                                                                                                                                                               0001-04-17 00:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              278.774658
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              280.321655
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.227661
#
# time                                                                                                                                                               0001-05-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              278.706543
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              280.213593
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.199493
#
# time                                                                                                                                                               0001-06-17 00:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.966461
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              278.691864
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.241058
#
# time                                                                                                                                                               0001-07-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              276.322845
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              275.406738
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.238922
#
# time                                                                                                                                                               0001-08-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              274.719147
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              272.345093
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              277.093170
#
# time                                                                                                                                                               0001-09-17 00:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              274.680359
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              272.443939
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              276.916809
#
# time                                                                                                                                                               0001-10-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              275.719604
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              274.555481
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              276.883728
#
# time                                                                                                                                                               ...  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name  ...
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                     ...
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                     ...
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                     ...
#
# time                                                                                                                                                               2014-03-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              399.020050
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              402.959412
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.080719
#
# time                                                                                                                                                               2014-04-17 00:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              399.094604
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              403.127563
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.061676
#
# time                                                                                                                                                               2014-05-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              398.623932
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              402.125000
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.122864
#
# time                                                                                                                                                               2014-06-17 00:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              397.337616
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              399.311371
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.363861
#
# time                                                                                                                                                               2014-07-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.648834
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.616882
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.680786
#
# time                                                                                                                                                               2014-08-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              394.573456
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              393.376556
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.770386
#
# time                                                                                                                                                               2014-09-17 00:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.026825
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              394.318665
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.734955
#
# time                                                                                                                                                               2014-10-17 12:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              396.668762
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              397.456665
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.880859
#
# time                                                                                                                                                               2014-11-17 00:00:00  \
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              398.189087
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              400.321228
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              396.056915
#
# time                                                                                                                                                               2014-12-17 12:00:00
# model       scenario   region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified historical World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              399.179688
#                        World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              402.195099
#                        World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              396.164307
#
# [3 rows x 24168 columns]

# %%
projection_concs = read_cmip6_concs_gmnhsh(TEST_PROJECTION_FILE)
projection_concs.head()
# Out:
# time                                                                                                                                                             2015-01-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              399.985443
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              403.364502
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              396.606384
#
# time                                                                                                                                                             2015-02-15 00:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              400.471680
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              404.067444
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              396.875916
#
# time                                                                                                                                                             2015-03-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              400.829407
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              404.587128
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              397.071716
#
# time                                                                                                                                                             2015-04-16 00:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              401.061829
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              404.826294
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              397.297333
#
# time                                                                                                                                                             2015-05-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              400.765961
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              403.919159
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              397.612732
#
# time                                                                                                                                                             2015-06-16 00:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              399.643005
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              401.186096
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              398.099915
#
# time                                                                                                                                                             2015-07-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              398.118835
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              397.617981
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              398.619690
#
# time                                                                                                                                                             2015-08-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              397.217529
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              395.575470
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              398.859619
#
# time                                                                                                                                                             2015-09-16 00:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              397.855652
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              396.728790
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              398.982513
#
# time                                                                                                                                                             2015-10-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              399.668549
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              400.064789
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              399.272278
#
# time                                                                                                                                                             ...  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name  ...
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                     ...
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                     ...
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                     ...
#
# time                                                                                                                                                             2500-03-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              581.471252
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              583.975220
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              578.967224
#
# time                                                                                                                                                             2500-04-16 00:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              581.205750
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              583.604553
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              578.806885
#
# time                                                                                                                                                             2500-05-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              580.177002
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              581.599060
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              578.754883
#
# time                                                                                                                                                             2500-06-16 00:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              578.151550
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              577.361206
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              578.941895
#
# time                                                                                                                                                             2500-07-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              576.184753
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              573.039368
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              579.330139
#
# time                                                                                                                                                             2500-08-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              575.389526
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              571.351440
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              579.427612
#
# time                                                                                                                                                             2500-09-16 00:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              576.097717
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              572.867310
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              579.328125
#
# time                                                                                                                                                             2500-10-16 12:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              578.050537
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              576.690613
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              579.410461
#
# time                                                                                                                                                             2500-11-16 00:00:00  \
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              579.750366
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              580.148682
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              579.352112
#
# time                                                                                                                                                             2500-12-16 12:00:00
# model       scenario region                    variable                               unit activity_id climate_model member_id   mip_era variable_standard_name
# unspecified ssp245-1 World                     mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              580.699402
#                      World|Northern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              582.227295
#                      World|Southern Hemisphere mole_fraction_of_carbon_dioxide_in_air ppm  input4MIPs  MAGICC7       unspecified CMIP6   NaN                              579.171448
#
# [3 rows x 5832 columns]

# %%
combined_concs = historical_concs.append(projection_concs)
# hack around Pyam's inability to handle NaN for now
combined_concs = combined_concs.timeseries().reset_index()
combined_concs = combined_concs.drop("variable_standard_name", axis="columns")
combined_concs = type(historical_concs)(combined_concs)

# %%
fig = plt.figure(figsize=(16, 9))

ax = fig.add_subplot(121)
combined_concs.filter(year=range(2010, 2021)).line_plot(
    color="scenario", 
    linestyle="region", 
    ax=ax
)

ax = fig.add_subplot(122)
combined_concs.line_plot(
    color="scenario", 
    linestyle="region", 
    legend=False, 
    ax=ax
);
# Out:
# Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
